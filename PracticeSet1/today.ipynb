# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

arr = np.random.rand(3,4)
arr
# Out:
# array([[0.97265617, 0.95011   , 0.8082867 , 0.96609042],
#        [0.0114567 , 0.20106941, 0.93366434, 0.39891251],
#        [0.47240931, 0.15803877, 0.78069658, 0.64461906]])

# %%
arr.shape
# Out:
# (3, 4)

# %%
arr.max()
# Out:
# np.float64(0.9726561688676408)
