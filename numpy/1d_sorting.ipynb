# %%
import numpy as np
x = np.array([[12,11,13],
              [21,25,20],
              [18,27,16]])
y = np.sort(x,axis=0)
print(y)
# Out:
# [[12 11 13]
#  [18 25 16]
#  [21 27 20]]

# %%
y1 = np.argsort(x,axis=0)
print(y1)
# Out:
# [[0 0 0]
#  [2 1 2]
#  [1 2 1]]

# %%
x = np.sort([7,2,3,9,6])[::-1]
print(x)
# Out:
# [9 7 6 3 2]

# %%
import numpy as np
x = np.array([4,2,3,9,7])
y = np.max(x)
print(y)
# Out:
# 9

# %%
y = np.min(x)
print(y)
# Out:
# 2

# %%
y = np.sum(x)
print(y)
# Out:
# 25

# %%
y = np.mean(x)
print(y)
# Out:
# 9

# %%
y = np.prod(x)
print(y)
# Out:
# 1512

# %%
y = np.var(x)
print(y)
# Out:
# 6.8

# %%
y = np.std(x)
print(y)
# Out:
# 2.6076809620810595

# %%
y = np.median(x)
print(y)
# Out:
# 4.0

# %%
print(np.full(5,7))
# Out:
# [7 7 7 7 7]

# %%
print(np.linspace(1,10,5))
# Out:
# [ 1.    3.25  5.5   7.75 10.  ]

# %%
a = np.array([[1,2,3],[4,5,6]])
print(a.shape)
# Out:
# (2, 3)

# %%
print(a.size)
# Out:
# 6

# %%
print(a.dtype)
# Out:
# int64

# %%
print(a.itemsize)
# Out:
# 8

# %%
print(a.ndim)
# Out:
# 2

# %%
print(a.reshape(2,3))
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(a.flatten())
# Out:
# [1 2 3 4 5 6]

# %%
print(a[a>3])
# Out:
# [4 5 6]

# %%
print(a[(a>3) & (a<5)])
# Out:
# [4]

# %%
a = np.array([[1,2,3],[4,5,6]])
print(a+10)
# Out:
# [[11 12 13]
#  [14 15 16]]

# %%
b = np.array([10,20,30])

# %%
print(a+b)
# Out:
# [[11 22 33]
#  [14 25 36]]

# %%
a = np.array([1,2,3,4])
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
b = a[1:3]
b[0] =100
print(a)
# Out:
# [  1 100   3   4]

# %%
b = np.array([8,7,4,5,3])
a = b[2:5]
a[1] = 200
print(b)
# Out:
# [  8   7   4 200   3]

# %%
a = np.array([1,2,3,4])
b = a[1:3].copy()
b[0] = 100
print(a)
print(b)
print(a)
# Out:
# [1 2 3 4]
# [100   3]
# [1 2 3 4]

# %%
a = np.array([2,4])
b = np.array([3,5])

print(np.concatenate((a,b)))
# Out:
# [2 4 3 5]

# %%
print(np.stack((a,b)))
print(np.vstack((a,b)))
# Out:
# [[2 4]
#  [3 5]]
# [[2 4]
#  [3 5]]

# %%
print(np.hstack((a,b)))
# Out:
# [2 4 3 5]

# %%
print(a+b)
# Out:
# [5 9]

# %%
c = np.array([1,2,3,4,5,6])
print(np.split(c,3))
# Out:
# [array([1, 2]), array([3, 4]), array([5, 6])]

# %%
a = np.array([[1,2],[3,4]])
b = np.array([[5,6],[7,8]])
print(np.dot(a,b))
# Out:
# [[19 22]
#  [43 50]]

# %%
a = np.array([[1,2],[3,4]])
b = np.array([[5,6],[7,8]])
print(a@b)
print(np.dot(a,b))
print(a.T)
# Out:
# [[19 22]
#  [43 50]]
# [[19 22]
#  [43 50]]
# [[1 3]
#  [2 4]]

# %%
a = np.array([[2,1],[1,2]])
print(np.linalg.det(a))
print(np.linalg.inv(a))
# Out:
# 2.9999999999999996
# [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]

# %%
a = np.array([10,20,30,40,50])
print(np.median(a))
print(np.percentile(a,50))
# Out:
# 30.0
# 30.0

# %%
a = np.array([1,2,np.nan,4])
print(np.isnan(a))
print(np.nanmean(a))
# Out:
# [False False  True False]
# 2.3333333333333335

# %%
a = np.array([1,1,2,3,2,2,])
print(np.unique(a))
# Out:
# [1 2 3]

# %%
a = np.array([1,10,20,30])
print(np.clip(a,5,25))
# Out:
# [ 5 10 20 25]
