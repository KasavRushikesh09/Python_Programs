# %%
import numpy as np
array1 = np.arange(1,8)
print(array1)
# Out:
# [1 2 3 4 5 6 7]

# %%
array1 = np.arange(11,20).reshape((3,3))
print(array1)
# Out:
# [[11 12 13]
#  [14 15 16]
#  [17 18 19]]

# %%
array1 = np.zeros((4,2))
print(array1)
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %%
array1 = np.ones((2,3))
print(array1)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
list2 = [[10,20,30,40,50],[7,9,2,3,4],[5,3,3,4,5]]
array2 = np.array(list2)
array2.itemsize
# Out:
# 8

# %%
list3 = [[10,20,30,40,50],[7,9,2,3,4],[5,3,3,4,5]]
array3 = np.array(list3)
print(array3[0,4])
# Out:
# 50

# %%
print(array3[:,1])
# Out:
# [20  9  3]

# %%
print(array3[2,:])
# Out:
# [5 3 3 4 5]

# %%
print(array3[1:3])
# Out:
# [[7 9 2 3 4]
#  [5 3 3 4 5]]

# %%
print(array3[1:6:2])
# Out:
# [[7 9 2 3 4]]

# %%
array4 = np.array([10,20,30,40,50,60,70])
print(array4[1:6])
# Out:
# [20 30 40 50 60]

# %%
print(array4[1:6:2])
# Out:
# [20 40 60]

# %%
print(array4[-1:-8:-1])
# Out:
# [70 60 50 40 30 20 10]

# %%
print(array4[::2])
# Out:
# [10 30 50 70]

# %%
print(array4[::-1])
# Out:
# [70 60 50 40 30 20 10]

# %%
array5 = [[15,16,17],[25,26,27],[35,36,37],[45,46,47]]
arr = np.array(array5)
print(arr)
# print(arr[:,1])
# print(arr[1,])
# print(arr[1:3,1:3])
# print(arr[:,1:3])
# print(arr[1:3,1])
# print(arr[1:3,:1])
# print(arr[1:3,1:])
print(arr[0:2,1:3])
# Out:
# [[15 16 17]
#  [25 26 27]
#  [35 36 37]
#  [45 46 47]]
# [[16 17]
#  [26 27]]

# %%
x = np.array([[1,2],[3,4]])
y = np.array([[11,12],[13,14]])
# z= y@x
#z= y/x
# z = y**x
z = x.transpose()
print(z)
# Out:
# [[1 3]
#  [2 4]]
